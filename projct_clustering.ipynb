# %%
import warnings
warnings.filterwarnings('ignore')


import pandas as pd
pd.options.display.max_columns=30
df=pd.read_csv("C:\\Users\\LEGION\\Downloads\\flight.csv")
df.head()
# Out:
#    MEMBER_NO   FFP_DATE FIRST_FLIGHT_DATE GENDER  FFP_TIER    WORK_CITY  \
# 0      54993  11/2/2006        12/24/2008   Male         6            .
# 1      28065  2/19/2007          8/3/2007   Male         6          NaN
# 2      55106   2/1/2007         8/30/2007   Male         6            .
# 3      21189  8/22/2008         8/23/2008   Male         5  Los Angeles
# 4      39546  4/10/2009         4/15/2009   Male         6      guiyang
#
#   WORK_PROVINCE WORK_COUNTRY   AGE  LOAD_TIME  FLIGHT_COUNT  BP_SUM  SUM_YR_1  \
# 0       beijing           CN  31.0  3/31/2014           210  505308  239560.0
# 1       beijing           CN  42.0  3/31/2014           140  362480  171483.0
# 2       beijing           CN  40.0  3/31/2014           135  351159  163618.0
# 3            CA           US  64.0  3/31/2014            23  337314  116350.0
# 4       guizhou           CN  48.0  3/31/2014           152  273844  124560.0
#
# ...

# %% [markdown]
# MEMBER_NO:  Unique ID assigned to each frequent flyer member.
#
# FFP_DATE:  The date when the individual enrolled in the frequent flyer program (FFP).
#
# FIRST_FLIGHT_DATE:  The date of the member's first flight.
#
# GENDER:  The gender of the member.
#
# FFP_TIER:  The membership level or tier in the frequent flyer program.
#
# WORK_CITY:  The city where the member is employed.
#
# WORK_PROVINCE:  The province/state where the member's workplace is located.
#
# WORK_COUNTRY:  The country where the member works.
#
# AGE:  The age of the member at the time of data collection.
#
# LOAD_TIME:  The date when the data was last updated or recorded.
#
# FLIGHT_COUNT:  The total number of flights taken by the member.
#
# BP_SUM:  The total sum of boarding passes, representing the number of segments flown.
#
# SUM_YR_1:  The total amount spent by the member in the first recorded year.
#
# SUM_YR_2:  The total amount spent by the member in the second recorded year.
#
# SEG_KM_SUM:  The total kilometers flown by the member.
#
# LAST_FLIGHT_DATE:  The date of the member’s most recent flight.
#
# LAST_TO_END:  The number of days between the last recorded flight and the data collection date.
#
# AVG_INTERVAL:  The average interval (in days) between flights.
#
# MAX_INTERVAL:  The longest interval (in days) between flights.
#
# EXCHANGE_COUNT:  The number of times the member exchanged frequent flyer points for rewards or services.
#
# avg_discount:  The average discount rate the member received on flights.
#
# Points_Sum:  The total number of frequent flyer points accumulated.
#
# Point_NotFlight:  The number of points earned from non-flight-related activities, such as hotel stays or other purchases.

# %%
df.shape
# Out:
# (62988, 23)

# %%
df.columns
# Out:
# Index(['MEMBER_NO', 'FFP_DATE', 'FIRST_FLIGHT_DATE', 'GENDER', 'FFP_TIER',
#        'WORK_CITY', 'WORK_PROVINCE', 'WORK_COUNTRY', 'AGE', 'LOAD_TIME',
#        'FLIGHT_COUNT', 'BP_SUM', 'SUM_YR_1', 'SUM_YR_2', 'SEG_KM_SUM',
#        'LAST_FLIGHT_DATE', 'LAST_TO_END', 'AVG_INTERVAL', 'MAX_INTERVAL',
#        'EXCHANGE_COUNT', 'avg_discount', 'Points_Sum', 'Point_NotFlight'],
#       dtype='object')

# %%
df.nunique()
# Out:
# MEMBER_NO            62988
# FFP_DATE              3068
# FIRST_FLIGHT_DATE     3406
# GENDER                   2
# FFP_TIER                 3
# WORK_CITY             3234
# WORK_PROVINCE         1165
# WORK_COUNTRY           118
# AGE                     84
# LOAD_TIME                1
# FLIGHT_COUNT           153
# BP_SUM               23449
# SUM_YR_1             15828
# SUM_YR_2             16767
# SEG_KM_SUM           29081
# LAST_FLIGHT_DATE       731
# LAST_TO_END            731
# AVG_INTERVAL         10706
# MAX_INTERVAL           706
# EXCHANGE_COUNT          28
# avg_discount         54179
# Points_Sum           25062
# Point_NotFlight         99
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62988 entries, 0 to 62987
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   MEMBER_NO          62988 non-null  int64
#  1   FFP_DATE           62988 non-null  object
#  2   FIRST_FLIGHT_DATE  62988 non-null  object
#  3   GENDER             62985 non-null  object
#  4   FFP_TIER           62988 non-null  int64
#  5   WORK_CITY          60719 non-null  object
#  6   WORK_PROVINCE      59740 non-null  object
#  7   WORK_COUNTRY       62962 non-null  object
#  8   AGE                62568 non-null  float64
#  9   LOAD_TIME          62988 non-null  object
#  10  FLIGHT_COUNT       62988 non-null  int64
#  11  BP_SUM             62988 non-null  int64
#  12  SUM_YR_1           62437 non-null  float64
#  13  SUM_YR_2           62850 non-null  float64
#  14  SEG_KM_SUM         62988 non-null  int64
#  15  LAST_FLIGHT_DATE   62988 non-null  object
# ...

# %%
df.isna().sum()
# Out:
# MEMBER_NO               0
# FFP_DATE                0
# FIRST_FLIGHT_DATE       0
# GENDER                  3
# FFP_TIER                0
# WORK_CITY            2269
# WORK_PROVINCE        3248
# WORK_COUNTRY           26
# AGE                   420
# LOAD_TIME               0
# FLIGHT_COUNT            0
# BP_SUM                  0
# SUM_YR_1              551
# SUM_YR_2              138
# SEG_KM_SUM              0
# LAST_FLIGHT_DATE        0
# LAST_TO_END             0
# AVG_INTERVAL            0
# MAX_INTERVAL            0
# EXCHANGE_COUNT          0
# avg_discount            0
# Points_Sum              0
# Point_NotFlight         0
# dtype: int64

# %%
#percentage of missing cell
round(df.isna().sum().sum() / df.size * 100, 1)
# Out:
# 0.5

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['FFP_TIER'] = df['FFP_TIER'].astype(object)

# %%
# Separate numerical and  categorical features
numerical = ['MEMBER_NO', 'AGE', 'FLIGHT_COUNT', 'BP_SUM', 'SUM_YR_1', 'SUM_YR_2', 'SEG_KM_SUM', 
             'LAST_TO_END', 'AVG_INTERVAL', 'MAX_INTERVAL', 'EXCHANGE_COUNT', 'avg_discount', 
             'Points_Sum', 'Point_NotFlight']

categorical = ['FFP_DATE', 'FFP_TIER', 'FIRST_FLIGHT_DATE', 'GENDER', 'WORK_CITY', 'WORK_PROVINCE', 
               'WORK_COUNTRY', 'LOAD_TIME', 'LAST_FLIGHT_DATE']

# %%
df[numerical].describe()
# Out:
#           MEMBER_NO           AGE  FLIGHT_COUNT         BP_SUM       SUM_YR_1  \
# count  62988.000000  62568.000000  62988.000000   62988.000000   62437.000000
# mean   31494.500000     42.476346     11.839414   10925.081254    5355.376064
# std    18183.213715      9.885915     14.049471   16339.486151    8109.450147
# min        1.000000      6.000000      2.000000       0.000000       0.000000
# 25%    15747.750000     35.000000      3.000000    2518.000000    1003.000000
# 50%    31494.500000     41.000000      7.000000    5700.000000    2800.000000
# 75%    47241.250000     48.000000     15.000000   12831.000000    6574.000000
# max    62988.000000    110.000000    213.000000  505308.000000  239560.000000
#
#             SUM_YR_2     SEG_KM_SUM   LAST_TO_END  AVG_INTERVAL  MAX_INTERVAL  \
# count   62850.000000   62988.000000  62988.000000  62988.000000  62988.000000
# mean     5604.026014   17123.878691    176.120102     67.749788    166.033895
# ...

# %%
df[categorical].describe()
# Out:
#          FFP_DATE  FFP_TIER FIRST_FLIGHT_DATE GENDER  WORK_CITY WORK_PROVINCE  \
# count       62988     62988             62988  62985      60719         59740
# unique       3068         3              3406      2       3234          1165
# top     1/13/2011         4         2/16/2013   Male  guangzhou     guangdong
# freq          184     58066                96  48134       9386         17509
#
#        WORK_COUNTRY  LOAD_TIME LAST_FLIGHT_DATE
# count         62962      62988            62988
# unique          118          1              731
# top              CN  3/31/2014        3/31/2014
# freq          57748      62988              959

# %%
# Create boxplot to see outliers
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(20, 6))
for i in range(0, len(numerical)):
    plt.subplot(1, len(numerical), i+1)
    sns.boxplot(y=df[numerical[i]], color='blue', orient='v')
    plt.tight_layout()

# %%
# Create distplot to see distribution of data
plt.figure(figsize=(15, 8))
for i in range(0, len(numerical)):
    plt.subplot(3, 5, i+1)
    sns.distplot(df[numerical[i]], color = 'blue')
    plt.tight_layout()
plt.show()

# %%
# Create violinplot to see outliers and distrubution
plt.figure(figsize=(25, 5))
for i in range (0, len(numerical)):
    plt.subplot(1, len(numerical), i+1)
    sns.violinplot(y=df[numerical[i]], color='blue', orient='v')
    plt.tight_layout()

# %% [markdown]
# ## Insight:
#
# 1. The dataset consists of 22 columns and 62,988 rows.
#
# 2. There are null values in 7 columns.
#
# 3. There are no duplicates in the data.
#
# 4. MEMBER_NO and avg_discount follow a normal distribution, while other columns show a positively skewed distribution (Mean > Median).
#
# 5. There is an anomaly in the AGE column, with a maximum age of 110 years.
#
# 6. GENDER is dominated by males, with 48,134 entries.
#
# 7. WORK_COUNTRY is dominated by China (CN), WORK_PROVINCE has the highest count in Guangdong, and WORK_CITY is most frequent in Guangzhou.
#
# 8. The columns FFP_DATE, FIRST_FLIGHT_DATE, LOAD_TIME, and LAST_FLIGHT_DATE should be of DateTime type instead of Object.
#
# 9. There are too many unique values in the categorical features WORK_CITY, WORK_PROVINCE, and WORK_COUNTRY, which suggests that these features may not be good candidates for clustering.
#
# 10. MEMBER_NO has unique values equal to the number of rows, so this column will not be used further.
#
# 11. The distribution in the FFP_TIER column indicates that this is a categorical feature.
#
# 12. The AGE and avg_discount columns have a normal distribution, while the other columns not previously mentioned appear to have a positively skewed distribution.

# %%
# Create count plot to see data distribution
plt.figure(figsize=(17,5))
for i in range(len(categorical)): 
    plt.subplot(3, 3, i+1)
    sns.countplot(x=df[categorical[i]], color="blue")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Insight:
#
# 1. The GENDER column shows that males are highly dominant.
#
# 2. There is not much information that can be gathered from the other columns; therefore, they need to be narrowed down to the top 10 columns to gain better insights.

# %%
# Top 10 values from WORK_CITY, WORK_PROVINCE, and WORK_COUNTRY
workcity = df["WORK_CITY"].value_counts().head(10)
workprovince = df["WORK_PROVINCE"].value_counts().head(10)
workcountry = df["WORK_COUNTRY"].value_counts().head(10)

fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(10,10))

sns.barplot(x=workcity.index, y = workcity.values, ax=ax[0], palette="magma")
sns.barplot(x=workprovince.index, y = workprovince.values, ax=ax[1], palette="magma")
sns.barplot(x=workcountry.index, y = workcountry.values, ax=ax[2], palette="magma")
plt.show()

# %%
# Function to check if conversion to datetime is possible for "FFP_DATE", "FIRST_FLIGHT_DATE", and "LAST_FLIGHT_DATE
def check_date_format(column):
    try:
        pd.to_datetime(column, errors='raise')
        return True
    except (ValueError, TypeError):
        return False

# %%
# Check each date column for invalid formats
date_columns = ["FFP_DATE", "FIRST_FLIGHT_DATE", "LAST_FLIGHT_DATE"]
errors = {col: check_date_format(df[col]) for col in date_columns}
errors
# Out:
# {'FFP_DATE': True, 'FIRST_FLIGHT_DATE': True, 'LAST_FLIGHT_DATE': False}

# %%
# Print results and identify invalid date formats
invalid_rows = []
for col, is_valid in errors.items():
    if not is_valid:
        print(f"Column '{col}' contains invalid date formats.")
        invalid_rows.extend(df[~df[col].apply(lambda x: check_date_format(pd.Series([x])))].index)
# Out:
# Column 'LAST_FLIGHT_DATE' contains invalid date formats.

# %%
# Drop rows with invalid date formats
if invalid_rows:
    df = df.drop(index=invalid_rows).reset_index(drop=True)
    print(f"Dropped {len(invalid_rows)} rows with invalid date formats.")
else:
    df_cleaned = df.copy()
    print("No invalid date formats found.")
# Out:
# Dropped 421 rows with invalid date formats.

# %%
ffp = pd.to_datetime(df["FFP_DATE"]).dt.year
firstflight = pd.to_datetime(df["FIRST_FLIGHT_DATE"]).dt.year
lastflight = pd.to_datetime(df["LAST_FLIGHT_DATE"]).dt.year

fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(10,10))

sns.countplot(x=ffp, ax=ax[0], palette="magma")
sns.countplot(x=firstflight, ax=ax[1], palette="magma")
sns.countplot(x=lastflight, ax=ax[2], palette="magma" )
plt.show()

# %% [markdown]
# ## Insights:
#
# 1. The majority of members work in China (CN), specifically in Guangdong Province and Guangzhou City.
#
# 2. In the FIRST_FLIGHT_DATE column, there is a value significantly different from others, indicating a flight date in 1905.
# 3. The highest number of member registrations occurred in 2012.
# 4. The first flights for most airline members also took place in 2012.

# %%
# Create heatmap to see corelation between numerical features
plt.figure(figsize=(15, 10))
sns.heatmap(df[numerical].corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Insights:
# 1. FFP_TIER has a strong positive correlation with Points_Sum, SEG_KM_SUM, SUM_YR_2, BP_SUM, and FLIGHT_COUNT.
#
# 2. AGE does not have a strong correlation with any feature.
# 3. FLIGHT_COUNT has a strong positive correlation with Points_Sum, EXCHANGE_COUNT, SEG_KM_SUM, SUM_YR_1, SUM_YR_2, and BP_SUM.
# 4. There is potential redundancy between BP_SUM and Points_Sum as well as SEG_KM_SUM. BP_SUM has a strong positive correlation with EXCHANGE_COUNT, SUM_YR_1, and SUM_YR_2.
# 5. SUM_YR_1 has a strong positive correlation with Points_Sum, SEG_KM_SUM, and SUM_YR_2.
# 6. SUM_YR_2 has a strong positive correlation with Points_Sum and SEG_KM_SUM.
# 7. SEG_KM_SUM has a strong positive correlation with Points_Sum and EXCHANGE_COUNT.
# 8. AVG_INTERVAL has a strong positive correlation with MAX_INTERVAL.
# 9. EXCHANGE_COUNT has a strong positive correlation with Points_Sum.

# %%
# Calculate the number of missing values
missing_values = df.isnull().sum()

# Calculate the percentage of missing values
missing_percentage = (df.isnull().sum() / len(df)) * 100

# Combine both into a DataFrame
missing_data = pd.DataFrame({'Missing Values': missing_values, 'Percentage': missing_percentage})

print(missing_data)
# Out:
#                    Missing Values  Percentage
# MEMBER_NO                       0    0.000000
# FFP_DATE                        0    0.000000
# FIRST_FLIGHT_DATE               0    0.000000
# GENDER                          3    0.004795
# FFP_TIER                        0    0.000000
# WORK_CITY                    2255    3.604136
# WORK_PROVINCE                3226    5.156073
# WORK_COUNTRY                   25    0.039957
# AGE                           419    0.669682
# LOAD_TIME                       0    0.000000
# FLIGHT_COUNT                    0    0.000000
# BP_SUM                          0    0.000000
# SUM_YR_1                      551    0.880656
# SUM_YR_2                      138    0.220564
# SEG_KM_SUM                      0    0.000000
# LAST_FLIGHT_DATE                0    0.000000
# LAST_TO_END                     0    0.000000
# AVG_INTERVAL                    0    0.000000
# MAX_INTERVAL                    0    0.000000
# ...

# %%
df_clean = df.copy() 

# Impute rows with mode & mean
df_clean['WORK_CITY'].fillna(df_clean['WORK_CITY'].mode()[0], inplace=True)
df_clean['WORK_PROVINCE'].fillna(df_clean['WORK_PROVINCE'].mode()[0], inplace=True)
df_clean['WORK_COUNTRY'].fillna(df_clean['WORK_COUNTRY'].mode()[0], inplace=True)
df_clean['GENDER'].fillna(df_clean['GENDER'].mode()[0], inplace=True)

df_clean['AGE'].fillna(df_clean['AGE'].mean(), inplace=True)
df_clean['SUM_YR_1'].fillna(df_clean['SUM_YR_1'].mean(), inplace=True)
df_clean['SUM_YR_2'].fillna(df_clean['SUM_YR_2'].mean(), inplace=True)

# Check missing values
df_clean.isna().sum()
# Out:
# MEMBER_NO            0
# FFP_DATE             0
# FIRST_FLIGHT_DATE    0
# GENDER               0
# FFP_TIER             0
# WORK_CITY            0
# WORK_PROVINCE        0
# WORK_COUNTRY         0
# AGE                  0
# LOAD_TIME            0
# FLIGHT_COUNT         0
# BP_SUM               0
# SUM_YR_1             0
# SUM_YR_2             0
# SEG_KM_SUM           0
# LAST_FLIGHT_DATE     0
# LAST_TO_END          0
# AVG_INTERVAL         0
# MAX_INTERVAL         0
# EXCHANGE_COUNT       0
# avg_discount         0
# Points_Sum           0
# Point_NotFlight      0
# dtype: int64

# %%
# Change date columns from object to datetime
df_clean['FFP_DATE'] = pd.to_datetime(df_clean['FFP_DATE'])
df_clean['LOAD_TIME'] = pd.to_datetime(df_clean['LOAD_TIME'])

# %%
# Extract loyalty / membership duration from FFP_DATE - LOAD_TIME (in months)
df_clean['LOYALTY'] = (df_clean['LOAD_TIME'].dt.year - df_clean['FFP_DATE'].dt.year) * 12 + (df_clean['LOAD_TIME'].dt.month - df_clean['FFP_DATE'].dt.month)

# Display the first few rows to check
print(df_clean[['FFP_DATE', 'LOAD_TIME', 'LOYALTY']].sample(5))
# Out:
#         FFP_DATE  LOAD_TIME  LOYALTY
# 50347 2011-06-14 2014-03-31       33
# 16111 2011-04-13 2014-03-31       35
# 50240 2013-01-01 2014-03-31       14
# 36690 2007-01-09 2014-03-31       86
# 62074 2010-02-28 2014-03-31       49

# %%
# Create heatmap to see corelation between numerical features after being cleaned

nums = ['MEMBER_NO', 'AGE', 'FLIGHT_COUNT', 'BP_SUM', 'SUM_YR_1', 'SUM_YR_2', 'SEG_KM_SUM', 'LAST_TO_END', 'AVG_INTERVAL', 
        'MAX_INTERVAL', 'EXCHANGE_COUNT', 'avg_discount', 'Points_Sum', 'Point_NotFlight', 'LOYALTY']
plt.figure(figsize=(15, 10))
sns.heatmap(df_clean[nums].corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# The main goal of classifying customers based on their characteristics is to understand and manage customer interactions across key dimensions important to the business. Based on this foundation, the following features have been selected for clustering:
#
# The "LOYALTY" feature represents Length: The duration of a customer's membership, from the time of first registration to the observation period (the longer the membership, the more "loyal" or valuable the customer is considered).
#
# The "AVG_INTERVAL" feature represents Interval: The time between flights (a smaller interval means the customer has flown recently, which is preferable as smaller intervals are better).
#
# The "FLIGHT_COUNT" feature represents Frequency: The number of flights taken by the customer during the observation period (the higher the count, the better, indicating frequent flyers).
#
# The "SEG_KM_SUM" feature represents Distance Traveled: The total distance flown during the observation period (the greater the distance, the higher the cost paid by the customer).

# %%
# Create boxplot to see outliers distribution before removing outliers
X_columns = ['LOYALTY', 'FLIGHT_COUNT', 'SEG_KM_SUM', 'AVG_INTERVAL']

plt.figure(figsize=(15, 7))
for i in range(0, len(X_columns)):
    plt.subplot(1, 5, i+1) 
    sns.boxplot(y=df_clean[X_columns[i]], color='blue')
    plt.title(X_columns[i])
    plt.tight_layout()
plt.show()

# %%
iqr_columns = ['FLIGHT_COUNT', 'SEG_KM_SUM', 'AVG_INTERVAL']
       
def remove_outliers_iqr(df, columns):
    for column in columns:
        Q1 = df[column].quantile(0.25)
        Q3 = df[column].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        df = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
    return df

# Remove outliers from the specified columns using the IQR method and update df_clean
df_clean = remove_outliers_iqr(df_clean, iqr_columns)

# Display the shape of the dataframe after removing outliers
print("Shape of dataframe after removing outliers:", df_clean.shape)
# Out:
# Shape of dataframe after removing outliers: (51092, 24)

# %%
# Create boxplot to see outliers distribution after removing outliers
X_columns = ['LOYALTY', 'FLIGHT_COUNT', 'SEG_KM_SUM', 'AVG_INTERVAL']

plt.figure(figsize=(15, 7))
for i in range(0, len(X_columns)):
    plt.subplot(1, 5, i+1)  # Adjusted to fit 16 plots
    sns.boxplot(y=df_clean[X_columns[i]], color='blue')
    plt.title(X_columns[i])
    plt.tight_layout()
plt.show()

# %%
# Create distplot to see distribution
plt.figure(figsize=(15, 8))
for i in range(0, len(X_columns)):
    plt.subplot(3, 5, i+1)
    sns.distplot(df_clean[X_columns[i]], color = 'blue')
    plt.tight_layout()
plt.show()

# %%
X_columns = ['LOYALTY', 'FLIGHT_COUNT', 'SEG_KM_SUM', 'AVG_INTERVAL']

X = df_clean[X_columns].values

from sklearn.preprocessing import StandardScaler
X_std = StandardScaler().fit_transform(X)
new_df = pd. DataFrame (data = X_std, columns = X_columns)
new_df.describe ()
# Out:
#             LOYALTY  FLIGHT_COUNT    SEG_KM_SUM  AVG_INTERVAL
# count  5.109200e+04  5.109200e+04  5.109200e+04  5.109200e+04
# mean   1.290581e-16  1.468592e-16  1.068067e-16  6.675419e-18
# std    1.000010e+00  1.000010e+00  1.000010e+00  1.000010e+00
# min   -1.274378e+00 -9.902221e-01 -1.296830e+00 -1.386544e+00
# 25%   -8.732420e-01 -8.394407e-01 -7.984114e-01 -7.035152e-01
# 50%   -2.533042e-01 -3.870966e-01 -2.951925e-01 -2.245623e-01
# 75%    8.042366e-01  5.175916e-01  5.704050e-01  5.251031e-01
# max    2.372314e+00  3.684000e+00  2.983043e+00  3.105202e+00

# %%
from sklearn.cluster import KMeans
inertia = []

for i in range(1, 11):
    kmeans = KMeans (n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=42)
    kmeans.fit(new_df.values)
    inertia.append(kmeans.inertia_)

    
plt.figure(figsize=(10, 4))
plt.plot (inertia)
plt.grid()

# %%
fig, ax = plt.subplots(figsize=(12,4))
sns.lineplot(x=range(1, 11), y=inertia, color="skyblue", linewidth = 3)
sns.scatterplot(x=range(1, 11), y=inertia, s=100, color='red')
plt.title("Inertia Score Elbow Method Kmean Clustering")
plt.grid()

plt.show()

# %% [markdown]
# From the Elbow graph above, it is observed that after the 4th point (k=5), the reduction in inertia becomes less significant. To confirm this further, we will examine the reduction in inertia at each step as the number of clusters increases.

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=5, init='k-means++', max_iter=300, n_init=10, random_state=42)
kmeans.fit(new_df.values)
# Add cluster labels to the dataframe
new_df['Cluster'] = kmeans.labels_

# %%
new_df.sample(10)
# Out:
#         LOYALTY  FLIGHT_COUNT  SEG_KM_SUM  AVG_INTERVAL  Cluster
# 1183  -0.180370     -0.839441    1.467570      2.561694        1
# 23304 -1.019110     -0.387097   -0.457210      0.897437        1
# 9913   0.950104      0.065248    0.481123      0.078427        2
# 12038 -1.164977      0.065248    0.664995     -0.396361        3
# 26363 -0.545040     -0.688659   -0.226466      2.336795        1
# 43723 -1.164977     -0.839441   -0.797169      1.512163        1
# 816    1.460641      2.176187    2.446224     -0.632335        4
# 20336 -0.946176     -0.236315   -0.285197      0.137776        3
# 28773 -0.836775     -0.387097   -0.315918      0.462631        3
# 37219 -1.274378     -0.085534   -0.453144     -0.090693        3

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=3, random_state=42)

pca.fit(new_df)
pcs = pca.transform(new_df)

data_pca = pd.DataFrame(data = pcs, columns = ['PC 1', 'PC 2', 'PC 3'])
data_pca['ClusterPCA'] = new_df['Cluster']
data_pca.sample(5)
# Out:
#            PC 1      PC 2      PC 3  ClusterPCA
# 28591 -0.344498  1.637723 -0.162232           2
# 35907 -0.388317  2.529251 -0.579422           2
# 27435 -1.082740  1.679097  0.311344           1
# 23174  0.903656  0.147069  0.634421           3
# 48369 -2.138248 -0.769318 -1.473882           0

# %%
fig, ax = plt.subplots(figsize=(12,5))

sns.scatterplot( x="PC 1", y="PC 2", hue="ClusterPCA", data=data_pca, edgecolor='black', linestyle='--',
                palette='viridis', ax=ax, s = 100)
plt.title("Segmentation with 5 clusters")
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Create a 3D scatter plot
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Scatter plot with clusters
for cluster in data_pca['ClusterPCA'].unique():
    ax.scatter(data_pca.loc[data_pca['ClusterPCA'] == cluster, 'PC 1'],
               data_pca.loc[data_pca['ClusterPCA'] == cluster, 'PC 2'],
               data_pca.loc[data_pca['ClusterPCA'] == cluster, 'PC 3'],
               label=f'Cluster {cluster}',
               alpha=0.8)

ax.set_xlabel('PC 1')
ax.set_ylabel('PC 2')
ax.set_zlabel('PC 3')
ax.set_title('PCA of Data with Clusters')
ax.legend()
plt.show()

# %%
# from yellowbrick.cluster import SilhouetteVisualizer
# from sklearn.cluster import KMeans

# for i in [2,3,4,5]:
#     model = KMeans(i, random_state=42)
#     visualizer = SilhouetteVisualizer(model, colors='yellowbrick')
#     visualizer.fit(new_df)        
#     visualizer.show()

# %%
# Add cluster to selected features
df_analysis = df_clean[X_columns]

df_analysis['Cluster'] = kmeans.labels_
display(df_analysis.groupby('Cluster').agg(['median','mean']))
# Out:
#         LOYALTY            FLIGHT_COUNT            SEG_KM_SUM                \
#          median       mean       median       mean     median          mean
# Cluster
# 0          26.0  29.892255          3.0   3.355030     4154.0   4640.195973
# 1          34.0  39.231056          4.0   4.424566     5767.0   6379.370846
# 2          81.0  82.548088          6.0   6.860470     8966.5   9650.857062
# 3          28.0  30.089691         10.0  10.780239    14805.5  15549.482401
# 4          56.0  57.752113         20.0  20.671831    27018.0  27121.329449
#
#         AVG_INTERVAL
#               median        mean
# Cluster
# 0          17.666667   24.365179
# 1         112.750000  117.146102
# 2          53.909091   53.673027
# 3          48.384615   49.257936
# 4          30.529825   31.450300

# %%
plt.figure(figsize=(10, 5))
ax = sns.countplot(data=df_analysis, x="Cluster", palette="viridis")

# Tambahkan label pada setiap batang
for container in ax.containers:
    ax.bar_label(container, fmt='%d')

plt.ylim(0, 20000)
plt.title("Total Customer per Cluster")
plt.xlabel("Cluster")
plt.show()

# %%
# Observe the value of each feature in each cluster

plt.figure(figsize=(15,3))
for i in range(len(X_columns)):
    plt.subplot(1, len(X_columns), i+1)
    plt.vlines(df_analysis[X_columns[i]].median(), ymin=0, ymax=4, color='grey', linestyle='--')
    group = df_analysis.groupby('Cluster')
    index = group[X_columns[i]].median().index
    value = group[X_columns[i]].median().values
    sns.barplot(y = index, x = value, orient='h', palette='viridis')
    plt.title(X_columns[i])

plt.tight_layout()
plt.show()

# %% [markdown]
# # Business Insight and Recomendations:

# %% [markdown]
# ### Explanation of Clusters Based on Customer Characteristics:
#
#
# **Cluster 0 (Inexperienced Flyers):**
#
# Customers in this cluster are new members of the airline program.
# They haven’t taken many flights yet, although their average interval between flights is short.
# These customers may include individuals who are just starting to explore or use air travel services, such as students or people beginning their professional careers.
#
# **Cluster 1 (Rare Flyers):**
#
# Customers in this cluster have been members longer than those in Cluster 0, but they still take relatively few flights and cover little distance.
# Their average interval between flights is the highest among all clusters, indicating that they rarely fly.
# Customers in this cluster might be individuals who only travel for personal reasons or take long vacations and rarely fly, or those who prefer other modes of transportation.
#
# **Cluster 2 (Infrequent Flyers):**
#
# Customers in this cluster have been members the longest compared to other clusters.
# Despite the long membership duration, they still take a relatively small number of flights and cover limited distances.
# Their average flight interval is moderate, suggesting they travel sporadically or only on special occasions.
# Customers in this cluster might include individuals who prefer to travel only during special times, such as annual vacations or rare business trips.
#
# **Cluster 3 (Regular Flyers):**
#
# Customers in this cluster have recently become members but take more flights than average.
# The total distance they travel is also significant.
# Their average interval between flights is moderate, indicating regular travel, possibly for business or work purposes.
# Customers in this cluster might include businesspeople or professionals who travel routinely for meetings or work-related purposes.
#
# **Cluster 4 (Frequent Flyers):**
#
# Customers in this cluster have the second-longest membership duration after Cluster 2.
# They take the most flights and cover the highest total distance compared to other clusters.
# Their average interval between flights is short, indicating they fly frequently.
# These customers may include business executives who frequently travel internationally or domestically, or travelers who often fly for leisure or recreational activities.

# %% [markdown]
# ### Business Recommendations for Each Cluster:

# %% [markdown]
# **Cluster 0 (Inexperienced Flyers):**
#
# **Business Recommendation:** Offer special promotions to attract new customers, such as discounts on their first flight or bonus points upon registration. Focus on providing easily understandable services and avoid complexity, as they are new to air travel.
#
# **Cluster 1 (Rare Flyers):**
#
# **Business Recommendation:** Introduce long-term holiday packages or special promotions for rarely visited destinations. Provide flexible booking options and exclusive offers to encourage them to travel more frequently.
#
# **Cluster 2 (Infrequent Flyers):**
#
# **Business Recommendation:** Develop an engaging loyalty program with points or rewards that can be accumulated from each flight. Offer holiday packages or flexible policies that allow them to plan long trips or vacations effectively.
#
# **Cluster 3 (Regular Flyers):**
#
# **Business Recommendation:** Focus on premium services and fast business perks, such as priority access, exclusive airport lounges, or superior customer service. Offer loyalty programs that provide added value and convenience for frequent travelers.
#
# **Cluster 4 (Frequent Flyers):**
#
# **Business Recommendation:** Enhance exclusive services for frequent flyers, such as automatic upgrades, global VIP lounge access, or exclusive opportunities for luxurious travel experiences. Provide flexible policies that accommodate their frequent travel needs.
